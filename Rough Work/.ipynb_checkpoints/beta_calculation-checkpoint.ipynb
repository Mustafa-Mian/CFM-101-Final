# %%
from IPython.display import display, Math, Latex

import pandas as pd
import numpy as np
import numpy_financial as npf
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker_file = pd.read_csv('Tickers_Example.csv')

# %%
def getBeta(cur_ticker):
    SP_ticker = '^GSPC'
    #TSX_ticker = 'TX60.TS'

    cur_stock = yf.Ticker(cur_ticker)
    SP_index = yf.Ticker(SP_ticker)
    #TSX_index = yf.Ticker(TSX_ticker)

    # Will edit these later
    start_date = '2018-01-01'
    end_date = '2022-05-25'

    cur_stock_hist = cur_stock.history(start=start_date, end=end_date)
    SP_index_hist = SP_index.history(start=start_date, end=end_date)
    #TSX_index_hist = TSX_index.history(start=start_date, end=end_date)

    prices = pd.DataFrame()
    prices[cur_ticker] = pd.DataFrame(cur_stock_hist['Close'])
    prices['S&P Index'] = SP_index_hist['Close']
    #prices['TSX Index'] = TSX_index_hist['Close']

    daily_returns = prices.pct_change()
    daily_returns.drop(index=daily_returns.index[0], inplace=True)

    SP_var = daily_returns['S&P Index'].var()
    SP_beta = daily_returns.cov() / SP_var

    return SP_beta.iat[0,1]

def calcBetas(ticker_file):
    columns = list(ticker_file.columns)
    betas = []
    for i in range(len(ticker_file)):
        cur_ticker = ticker_file[columns[0]].iloc[i]

        cur_beta = getBeta(cur_ticker)
        stock_details = {
            "name": cur_ticker,
            "beta": cur_beta
        }

        betas = betas + [stock_details]

    for i in range(len(betas)):
        print(betas[i])

# %%
calcBetas(ticker_file)
# Out:
# $AGN: possibly delisted; no timezone found
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_44387/493658996.py:22: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_44387/493658996.py:22: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# $CELG: possibly delisted; no timezone found
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_44387/493658996.py:22: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# $MON: possibly delisted; no timezone found
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_44387/493658996.py:22: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# $RTN: possibly delisted; no timezone found
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_44387/493658996.py:22: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_44387/493658996.py:22: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_44387/493658996.py:22: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_44387/493658996.py:22: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_44387/493658996.py:22: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# {'name': 'ABBV', 'beta': 0.7292586238996573}
# {'name': 'ABT', 'beta': 0.8699328181021369}
# {'name': 'ACN', 'beta': 1.072872814094583}
# {'name': 'AGN', 'beta': nan}
# {'name': 'AIG', 'beta': 1.2755815773452872}
# {'name': 'AMZN', 'beta': 1.0149209979342053}
# {'name': 'AXP', 'beta': 1.3126670241659324}
# {'name': 'BA', 'beta': 1.5319711195748649}
# {'name': 'BAC', 'beta': 1.2541661564373603}
# {'name': 'BB.TO', 'beta': 1.0730600646175206}
# {'name': 'BIIB', 'beta': 0.8288621265730518}
# {'name': 'BK', 'beta': 1.0154029975205616}
# {'name': 'BLK', 'beta': 1.2016223384140536}
# {'name': 'BMY', 'beta': 0.598509426728439}
# {'name': 'C', 'beta': 1.3435027221907154}
# {'name': 'CAT', 'beta': 1.029998234358059}
# {'name': 'CELG', 'beta': nan}
# {'name': 'CL', 'beta': 0.5633314343452341}
# {'name': 'KO', 'beta': 0.6648232128155188}
# {'name': 'LLY', 'beta': 0.6973976654286574}
# {'name': 'LMT', 'beta': 0.7122582410272595}
# {'name': 'MO', 'beta': 0.6169285998229095}
# {'name': 'MON', 'beta': nan}
# {'name': 'MRK', 'beta': 0.6003577346432623}
# {'name': 'PEP', 'beta': 0.7197918511482791}
# {'name': 'PFE', 'beta': 0.6130859560115951}
# {'name': 'PG', 'beta': 0.6016332006475804}
# {'name': 'PM', 'beta': 0.7021907472525484}
# {'name': 'PYPL', 'beta': 1.3016870071113382}
# {'name': 'QCOM', 'beta': 1.2611211475019644}
# {'name': 'RTN', 'beta': nan}
# {'name': 'RY.TO', 'beta': 0.6940823124479475}
# {'name': 'SHOP.TO', 'beta': 1.314274636832347}
# {'name': 'T.TO', 'beta': 0.521798160386409}
# {'name': 'TD.TO', 'beta': 0.7487981738335904}
# {'name': 'TXN', 'beta': 1.1716135335323863}
# {'name': 'UNH', 'beta': 0.9852545190045374}
# {'name': 'UNP', 'beta': 0.9743672437806021}
# {'name': 'UPS', 'beta': 0.850793642588294}
# {'name': 'USB', 'beta': 1.0923762860782473}
