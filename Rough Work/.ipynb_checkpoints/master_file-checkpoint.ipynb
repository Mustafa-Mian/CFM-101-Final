# %%
import subprocess
import pkg_resources
def check_and_update_yfinance():
    try:
        # Check the installed version of yfinance
        installed_version = pkg_resources.get_distribution("yfinance").version
        print(f"Currently installed yfinance version: {installed_version}")
    except pkg_resources.DistributionNotFound:
        print("yfinance is not installed.")
        installed_version = None
    # Update or install the latest version
    print("Checking for the latest version of yfinance...")
    try:
        subprocess.check_call(["pip", "install", "--upgrade", "yfinance"])
        print("yfinance has been updated to the latest version.")
    except subprocess.CalledProcessError as e:
        print("An error occurred while updating yfinance:", e)
if __name__ == "__main__":
    check_and_update_yfinance()
# Out:
# Currently installed yfinance version: 0.2.50
# Checking for the latest version of yfinance...
# Requirement already satisfied: yfinance in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (0.2.50)
# Requirement already satisfied: pandas>=1.3.0 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (2.32.2)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from requests>=2.31->yfinance) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/venv/lib/python3.9/site-packages (from requests>=2.31->yfinance) (2024.6.2)
# yfinance has been updated to the latest version.

# %%
from IPython.display import display, Math, Latex

import pandas as pd
import numpy as np
import numpy_financial as npf
import yfinance as yf
import matplotlib.pyplot as plt
import random
from datetime import datetime
import itertools # Library for creating and using "Iterators" on multiple python types.

# %%
investment_size = 1000000
min_stocks = 12
max_stocks = 24
flat_fee = 3.95
fee_per_share = 0.001
ticker_file = pd.read_csv('Tickers_Example.csv', header=None)
ticker_file.rename(columns={0: 'name'}, inplace=True)

# %%
def clean_data(tickers):
    filtered_stocks = pd.DataFrame()
    start_date = "2023-10-01"
    end_date = "2024-09-30"
    for ticker in tickers['name']:
        try:
            stock = yf.Ticker(ticker)
            info = stock.fast_info
            if info['currency'] not in ["USD", "CAD"]: # Enusring stock is listed, traded in CAD or USD
                continue
    
            hist = stock.history(start=start_date, end=end_date, interval="1d")
            hist['Month'] = hist.index.to_period('M')
            monthly_data = hist.groupby('Month').filter(lambda x: len(x) >= 18)

            avg_monthly_volume = monthly_data.groupby('Month')['Volume'].mean().mean()
            if avg_monthly_volume >= 100000:
                filtered_stocks = pd.concat([filtered_stocks, pd.DataFrame({"Ticker": [ticker]})])
                
        except Exception as e:
            continue
    
    return filtered_stocks.reset_index(drop=True)

# %%
aapl = yf.Ticker('AAPL')
aapl_hist = aapl.history(start='2023-09-30')
aapl_hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-10-02 00:00:00-04:00  170.161094  173.222047  169.872879  172.675446
# 2023-10-03 00:00:00-04:00  171.194668  172.556205  169.763586  171.333801
# 2023-10-04 00:00:00-04:00  170.031901  173.132615  169.912648  172.586014
# 2023-10-05 00:00:00-04:00  172.715179  174.364916  171.612043  173.828262
# 2023-10-06 00:00:00-04:00  172.725152  176.889242  172.108976  176.392334
# ...                               ...         ...         ...         ...
# 2024-11-14 00:00:00-05:00  225.020004  228.869995  225.000000  228.220001
# 2024-11-15 00:00:00-05:00  226.399994  226.919998  224.270004  225.000000
# 2024-11-18 00:00:00-05:00  225.250000  229.740005  225.169998  228.020004
# 2024-11-19 00:00:00-05:00  226.979996  230.160004  226.660004  228.279999
# 2024-11-20 00:00:00-05:00  228.104996  229.929993  225.889999  226.887100
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-10-02 00:00:00-04:00  52164500        0.0           0.0
# 2023-10-03 00:00:00-04:00  49594600        0.0           0.0
# 2023-10-04 00:00:00-04:00  53020300        0.0           0.0
# 2023-10-05 00:00:00-04:00  48527900        0.0           0.0
# 2023-10-06 00:00:00-04:00  57224100        0.0           0.0
# ...                             ...        ...           ...
# 2024-11-14 00:00:00-05:00  44923900        0.0           0.0
# 2024-11-15 00:00:00-05:00  47923700        0.0           0.0
# 2024-11-18 00:00:00-05:00  44686000        0.0           0.0
# 2024-11-19 00:00:00-05:00  36211800        0.0           0.0
# 2024-11-20 00:00:00-05:00  16423925        0.0           0.0
#
# [288 rows x 7 columns]

# %%
ticker_file = clean_data(ticker_file)
# Out:
# $AAPL: possibly delisted; no price data found  (period=5d)
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# $ABT: possibly delisted; no price data found  (period=5d)
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# $AGN: possibly delisted; no price data found  (period=5d)
# $AIG: possibly delisted; no price data found  (period=5d)
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# $BA: possibly delisted; no price data found  (1d 2023-10-01 -> 2024-09-30)
# $BAC: possibly delisted; no price data found  (period=5d)
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# $BIIB: possibly delisted; no price data found  (period=5d)
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# $C: possibly delisted; no price data found  (1d 2023-10-01 -> 2024-09-30)
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# $CELG: possibly delisted; no price data found  (period=5d)
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# $MON: possibly delisted; no price data found  (period=5d) (Yahoo error = "No data found, symbol may be delisted")
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# Failed to get ticker 'RTN' reason: Expecting value: line 1 column 1 (char 0)
# $RTN: possibly delisted; no price data found  (period=5d) (Yahoo error = "No data found, symbol may be delisted")
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# $T.TO: possibly delisted; no price data found  (1d 2023-10-01 -> 2024-09-30)
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_263/194688612.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   hist['Month'] = hist.index.to_period('M')

# %%
ticker_file
# Out:
#      Ticker
# 0      AAPL
# 1      ABBV
# 2       ABT
# 3       ACN
# 4       AIG
# 5      AMZN
# 6       AXP
# 7        BA
# 8       BAC
# 9     BB.TO
# 10     BIIB
# 11      BLK
# 12      BMY
# 13      CAT
# 14       CL
# 15       KO
# 16      LLY
# 17      LMT
# 18       MO
# 19      MRK
# 20      PEP
# 21       PG
# 22       PM
# 23     PYPL
# 24     QCOM
# 25    RY.TO
# 26  SHOP.TO
# 27     T.TO
# 28    TD.TO
# 29      TXN
# 30      UNH
# 31      UNP
# 32      UPS

# %%
def getBeta(cur_ticker):
    SP_ticker = '^GSPC'

    cur_stock = yf.Ticker(cur_ticker)
    SP_index = yf.Ticker(SP_ticker)

    # Will edit these later
    start_date = '2023-11-14'
    end_date = '2024-11-18'

    cur_stock_hist = cur_stock.history(start=start_date, end=end_date)
    SP_index_hist = SP_index.history(start=start_date, end=end_date)

    prices = pd.DataFrame()
    prices[cur_ticker] = pd.DataFrame(cur_stock_hist['Close'])
    prices['S&P Index'] = SP_index_hist['Close']

    daily_returns = prices.pct_change(fill_method=None).dropna()
    daily_returns.drop(index=daily_returns.index[0], inplace=True)

    SP_var = daily_returns['S&P Index'].var()
    SP_beta = daily_returns.cov() / SP_var
    currency = cur_stock.fast_info.currency
    todays_price = cur_stock.fast_info.last_price

    if currency == 'USD':
        cadusd = yf.Ticker('CADUSD=x')
        exchange = cadusd.fast_info.last_price
        todays_price = todays_price / exchange

    return SP_beta.iat[0,1], todays_price

# %%
# Gets average of daily growth
def getGrowth(cur_ticker):
    # Fetch data for current stock
    cur_stock = yf.Ticker(cur_ticker)
    start_date = '2023-11-14'
    end_date = '2024-11-18'
    cur_stock_hist = cur_stock.history(start=start_date, end=end_date)

    prices = pd.DataFrame()
    prices[cur_ticker] = cur_stock_hist['Close']
    
    daily_returns = prices.pct_change(fill_method=None).dropna()
    SP_growth = daily_returns.mean()
    
    return SP_growth[cur_ticker] * 100

# %%
def getVolatility(cur_ticker):
    start_date = '2023-11-14'
    end_date = '2024-11-18'
    stock_data = yf.Ticker(cur_ticker).history(start=start_date, end=end_date)
    stock_data['Daily Return'] = stock_data['Close'].pct_change(fill_method=None).dropna()
    
    volatility = stock_data['Daily Return'].std()
    return volatility

# %%
# Initialize data structures
stock_data = []
beta_data = []
volatility_data = []
growth_data = []

# Iterate through the tickers and gather data
for i in range(len(ticker_file)):
    cur_ticker = ticker_file['Ticker'].iloc[i]

    # Replace these functions with your actual implementations
    beta, price = getBeta(cur_ticker)
    beta_data.append({"name": cur_ticker, "beta": beta})
    growth = getGrowth(cur_ticker)
    growth_data.append({"name": cur_ticker, "growth": growth})
    volatility = getVolatility(cur_ticker)
    volatility_data.append({"name": cur_ticker, "volatility": volatility})

    # Store combined stock details
    stock_details = {
        "name": cur_ticker,
        "beta": beta,
        "growth": growth,
        "volatility": volatility,
        "price": price
    }
    stock_data.append(stock_details)

# Sort the data by each criterion
sorted_betas = sorted(beta_data, key=lambda d: d['beta'], reverse=True)
sorted_growth = sorted(growth_data, key=lambda d: d['growth'], reverse=True)
sorted_volatility = sorted(volatility_data, key=lambda d: d['volatility'], reverse=True)

lists = [sorted_betas, sorted_growth, sorted_volatility]

# Step 1: Calculate average index position for each stock
index_map = {}
for lst in lists:
    for index, stock in enumerate(lst):
        name = stock["name"]
        if name not in index_map:
            index_map[name] = []
        index_map[name].append(index)

# Compute average index positions
average_positions = [
    {"name": name, "average_index": np.sum(indices) / len(indices)}
    for name, indices in index_map.items()
]

# Step 2: Sort stocks by their average index
sorted_by_average = sorted(average_positions, key=lambda x: x["average_index"])

# Final result: A list of stocks sorted by the average of their index positions
result = [{"name": stock["name"], "average_index": stock["average_index"]} for stock in sorted_by_average]
# Out:
# $BAC: possibly delisted; no price data found  (period=1y)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 12
#       9 cur_ticker = ticker_file['Ticker'].iloc[i]
#      11 # Replace these functions with your actual implementations
# ---> 12 beta, price = getBeta(cur_ticker)
#      13 beta_data.append({"name": cur_ticker, "beta": beta})
#      14 growth = getGrowth(cur_ticker)
#
# Cell In[35], line 24, in getBeta(cur_ticker)
#      22 SP_beta = daily_returns.cov() / SP_var
#      23 currency = cur_stock.fast_info.currency
# ---> 24 todays_price = cur_stock.fast_info.last_price
#      26 if currency == 'USD':
#      27     cadusd = yf.Ticker('CADUSD=x')
#
# File /opt/anaconda3/envs/venv/lib/python3.9/site-packages/yfinance/scrapers/quote.py:249, in FastInfo.last_price(self)
#     247 if self._last_price is not None:
#     248     return self._last_price
# --> 249 prices = self._get_1y_prices()
#     250 if prices.empty:
#     251     md = self._get_exchange_metadata()
#
# File /opt/anaconda3/envs/venv/lib/python3.9/site-packages/yfinance/scrapers/quote.py:134, in FastInfo._get_1y_prices(self, fullDaysOnly)
#     132 self._md = self._tkr.get_history_metadata(proxy=self.proxy)
#     133 try:
# --> 134     ctp = self._md["currentTradingPeriod"]
#     135     self._today_open = pd.to_datetime(ctp["regular"]["start"], unit='s', utc=True).tz_convert(self.timezone)
#     136     self._today_close = pd.to_datetime(ctp["regular"]["end"], unit='s', utc=True).tz_convert(self.timezone)
#
# KeyError: 'currentTradingPeriod'

# %%
best_stocks = []
for i in range(24):
    best_stocks += [result[i]["name"]]

# %%
filtered_stocks = []
for stock in best_stocks:
    for stock_stats in stock_data:
        if (stock == stock_stats["name"]):
            filtered_stocks += [stock_stats]

filtered_stocks
# Out:
# [{'name': 'SHOP.TO',
#   'beta': 1.7021574350324524,
#   'growth': 0.26162788863493874,
#   'volatility': 0.03218113332253605,
#   'price': 145.99000549316406},
#  {'name': 'QCOM',
#   'beta': 2.0030946882358522,
#   'growth': 0.1272831016990407,
#   'volatility': 0.023514063268838006,
#   'price': 229.90882769912741},
#  {'name': 'PYPL',
#   'beta': 1.0852248592784912,
#   'growth': 0.1871698365693403,
#   'volatility': 0.021464949787473032,
#   'price': 117.37618657774405},
#  {'name': 'CAT',
#   'beta': 1.2417419311764322,
#   'growth': 0.19334545789222712,
#   'volatility': 0.016676275093046613,
#   'price': 533.6715161438469},
#  {'name': 'AMZN',
#   'beta': 1.5205507587538978,
#   'growth': 0.1447882125759792,
#   'volatility': 0.01714684301151393,
#   'price': 285.6028380689949},
#  {'name': 'C',
#   'beta': 1.089628080257933,
#   'growth': 0.2016036097524226,
#   'volatility': 0.016645208045475212,
#   'price': 95.75462683785601},
#  {'name': 'TXN',
#   'beta': 1.4175192576993116,
#   'growth': 0.1418429021637815,
#   'volatility': 0.01711322269618,
#   'price': 280.66157358412704},
#  {'name': 'AXP',
#   'beta': 1.003442540305336,
#   'growth': 0.25468561622105956,
#   'volatility': 0.015039844666732902,
#   'price': 398.58211563933094},
#  {'name': 'USB',
#   'beta': 0.9952650424416308,
#   'growth': 0.1596892379177496,
#   'volatility': 0.016819086396540908,
#   'price': 70.3483225365512},
#  {'name': 'LLY',
#   'beta': 0.848680851565904,
#   'growth': 0.09923310280063842,
#   'volatility': 0.018779831250124095,
#   'price': 1018.5863487816404},
#  {'name': 'BAC',
#   'beta': 0.8327977416626825,
#   'growth': 0.20765825917779487,
#   'volatility': 0.014830105070233506,
#   'price': 64.78093754783917},
#  {'name': 'BB.TO',
#   'beta': 1.3280408521050178,
#   'growth': -0.1154870908229487,
#   'volatility': 0.032721879820658405,
#   'price': 3.2699999809265137},
#  {'name': 'BLK',
#   'beta': 0.8397307533007077,
#   'growth': 0.17745597327514467,
#   'volatility': 0.01146234118111759,
#   'price': 1435.0771164047576},
#  {'name': 'BK',
#   'beta': 0.645791458284138,
#   'growth': 0.22385776467869495,
#   'volatility': 0.010949633391632551,
#   'price': 108.33114887216044},
#  {'name': 'AAPL',
#   'beta': 0.9798107471154058,
#   'growth': 0.08406680492612763,
#   'volatility': 0.014148413960834823,
#   'price': 318.64237002722257},
#  {'name': 'BA',
#   'beta': 0.7521002891435371,
#   'growth': -0.13196029494638642,
#   'volatility': 0.021309861156697505,
#   'price': 203.23432306330412},
#  {'name': 'BMY',
#   'beta': 0.13914268899927043,
#   'growth': 0.07769786702137277,
#   'volatility': 0.018029231997723317,
#   'price': 81.27976677781993},
#  {'name': 'AIG',
#   'beta': 0.7018136157171363,
#   'growth': 0.081644552823961,
#   'volatility': 0.012540012049882336,
#   'price': 105.1067617126921},
#  {'name': 'ACN',
#   'beta': 0.6974927149534287,
#   'growth': 0.0560232826215967,
#   'volatility': 0.014734509010375945,
#   'price': 494.0576106707134},
#  {'name': 'UPS',
#   'beta': 0.6184227837237398,
#   'growth': 0.0018521521982555707,
#   'volatility': 0.016556653435533468,
#   'price': 185.92589338604793},
#  {'name': 'ABBV',
#   'beta': 0.1987382531084924,
#   'growth': 0.09551083204328378,
#   'volatility': 0.014568302212670338,
#   'price': 232.50509108577438},
#  {'name': 'PM',
#   'beta': 0.09146175585301405,
#   'growth': 0.1672228861100828,
#   'volatility': 0.01230019575482923,
#   'price': 180.81711360928628},
#  {'name': 'UNH',
#   'beta': 0.20584151412275697,
#   'growth': 0.053899132178630786,
#   'volatility': 0.015341456692821732,
#   'price': 805.3997217840432},
#  {'name': 'BIIB',
#   'beta': 0.6601931925145121,
#   'growth': -0.1219782472934833,
#   'volatility': 0.01619386922306927,
#   'price': 216.95541223218387}]

# %%
def generate_numbers(n, min_value, max_value, total_sum):
    total_lower = n * min_value
    total_upper = n * max_value
    if total_sum < total_lower or total_sum > total_upper:
        raise ValueError("Cannot generate numbers with the given constraints.")

    # Calculate the adjusted sum we need to distribute
    remaining_sum = total_sum - total_lower
    adjusted_upper_bounds = [max_value - min_value] * n

    # Generate initial random values
    u = [random.random() for _ in range(n)]
    adjusted_weights = [u_i * adjusted_upper_bounds[i] for i, u_i in enumerate(u)]
    adjusted_weights_sum = np.sum(adjusted_weights)

    # Scale the weights to match the remaining sum
    scaling_factor = remaining_sum / adjusted_weights_sum
    adjusted_weights = [w_i * scaling_factor for w_i in adjusted_weights]

    # Compute the final values
    x = [min_value + w_i for w_i in adjusted_weights]

    return x

# %%
if True:
    n = 12
    min_value = 100 / (2 * n)
    max_value = 15
    total_sum = 100

    lst = generate_numbers(n, min_value, max_value, total_sum)
    total = 0
    for i in range(len(lst)):
        total += lst[i]

    print(min_value)
    print(total)
    display(lst)
# Out:
# 4.166666666666667
# 100.0
# [9.060921842442447,
#  8.42194976862787,
#  9.969718535832811,
#  8.963875977789343,
#  9.681184476806681,
#  7.864085264168553,
#  8.122461019663227,
#  8.606204119100134,
#  5.2034907127025445,
#  9.091963758542278,
#  8.623732877478904,
#  6.390411646845214]

# %%
def create_portfolios(stock_details, budget):
    best_portfolio = pd.DataFrame()
    for n in range(12, 25):
        stocks = filtered_stocks[:n]
        max_weight = 15
        min_weight = 100 / (2 * n)
        generate = True
        weights = []
        while generate == True:
            weights = generate_numbers(n, min_weight, max_weight, 100)
            # We want to regenerate the weights in the chance one of them violates the restrictions (may happen due to rounding errors)
            for number in weights:
                if number > max_weight:
                    continue
                elif number < min_weight:
                    continue      
            generate = False
        
        weights.sort(reverse=True)
        zipped = zip(filtered_stocks, weights)
        
        for stock, weighting in zipped:
            

        #print(weights)
        #print(len(weights))
        print(zipped)

create_portfolios(filtered_stocks, investment_size)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 26
#      22         #print(weights)
#      23         #print(len(weights))
#      24         print(zipped)
# ---> 26 create_portfolios(filtered_stocks, investment_size)
#
# NameError: name 'filtered_stocks' is not defined

# %%
def generate_portfolios(stock_details, budget=1_000_000):
    portfolios = []

    # Extract stock names for combinations
    stock_names = [stock["name"] for stock in stock_details]

    for n in range(12, 25):  # From 12 to 24 stocks
        combinations = itertools.combinations(stock_details, n)

        for combo in combinations:
            # Randomly assign weights to ensure sum = 1
            weights = np.random.dirichlet(np.ones(n), size=1).flatten()

            # Enforce constraints
            min_weight = 100 / (2 * n) / 100  # Convert to fraction
            max_weight = 0.15
            if any(weights < min_weight) or any(weights > max_weight):
                print('some weight constraint was violated.')
                continue

            # Normalize weights to sum to 1
            weights /= weights.sum()

            # Allocate budget to stocks
            allocation = {}
            total_fee = 0
            for stock, weight in zip(combo, weights):
                amount = weight * budget
                shares = amount / stock["price"]
                fee = min(3.95, 0.001 * shares * stock["price"])
                total_fee += fee
                allocation[stock["name"]] = {"shares": shares, "value": shares * stock["price"]}

            # Check if we are close enough to spending the full budget
            total_value = budget - total_fee
            if abs(total_value - budget) > 1:  # Ensure we spent all
                print('we were over budget.')
                continue

            # Calculate portfolio return and risk (Sharpe ratio)
            portfolio_return = sum(stock["return"] * weight for stock, weight in zip(combo, weights))
            portfolio_std_dev = np.sqrt(sum((stock["std_dev"] ** 2) * (weight ** 2) for stock, weight in zip(combo, weights)))
            sharpe_ratio = portfolio_return / portfolio_std_dev if portfolio_std_dev > 0 else 0

            # Store portfolio
            portfolios.append({
                "stocks": [stock["name"] for stock in combo],
                "weights": weights,
                "return": portfolio_return,
                "std_dev": portfolio_std_dev,
                "sharpe_ratio": sharpe_ratio,
                "allocation": allocation,
            })

    return portfolios

# %% [markdown]
# # Generate all portfolios
# portfolios = generate_portfolios(filtered_stocks)
#
# # Find the portfolio with the highest Sharpe ratio
# best_portfolio = max(portfolios, key=lambda p: p['sharpe_ratio'])
#
# # Output the result
# print("Best Portfolio:")
# print(f"Stocks: {best_portfolio['stocks']}")
# print(f"Weights: {best_portfolio['weights']}")
# print(f"Return: {best_portfolio['return']:.4f}")
# print(f"Std Dev: {best_portfolio['std_dev']:.4f}")
# print(f"Sharpe Ratio: {best_portfolio['sharpe_ratio']:.4f}")
# print("Allocation:")
# for stock, details in best_portfolio['allocation'].items():
#     print(f"{stock}: {details['shares']} shares, Value: {details['value']:.2f} CAD")
