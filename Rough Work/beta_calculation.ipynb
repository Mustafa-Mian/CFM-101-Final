# %%
from IPython.display import display, Math, Latex

import pandas as pd
import numpy as np
import numpy_financial as npf
import yfinance as yf
import matplotlib.pyplot as plt

# %%
ticker_file = pd.read_csv('Tickers_Example.csv')

# %%
def getBeta(cur_ticker):
    SP_ticker = '^GSPC'

    cur_stock = yf.Ticker(cur_ticker)
    SP_index = yf.Ticker(SP_ticker)

    # Will edit these later
    start_date = '2018-01-01'
    end_date = '2022-05-25'

    cur_stock_hist = cur_stock.history(start=start_date, end=end_date)
    SP_index_hist = SP_index.history(start=start_date, end=end_date)

    prices = pd.DataFrame()
    prices[cur_ticker] = pd.DataFrame(cur_stock_hist['Close'])
    prices['S&P Index'] = SP_index_hist['Close']

    daily_returns = prices.pct_change()
    daily_returns.drop(index=daily_returns.index[0], inplace=True)

    SP_var = daily_returns['S&P Index'].var()
    SP_beta = daily_returns.cov() / SP_var

    return SP_beta.iat[0,1]

def calcBetas(ticker_file):
    columns = list(ticker_file.columns)
    betas = []
    for i in range(len(ticker_file)):
        cur_ticker = ticker_file[columns[0]].iloc[i]

        cur_beta = getBeta(cur_ticker)
        stock_details = {
            "name": cur_ticker,
            "beta": cur_beta
        }

        betas = betas + [stock_details]

    for i in range(len(betas)):
        print(betas[i])

# %%
calcBetas(ticker_file)
# Out:
# $AGN: possibly delisted; no timezone found
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_20046/310774108.py:18: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_20046/310774108.py:18: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# $CELG: possibly delisted; no timezone found
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_20046/310774108.py:18: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# $MON: possibly delisted; no timezone found
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_20046/310774108.py:18: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# $RTN: possibly delisted; no timezone found
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_20046/310774108.py:18: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_20046/310774108.py:18: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_20046/310774108.py:18: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_20046/310774108.py:18: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# /var/folders/7x/z5l3v4x13gv5wlh0qdjwgllh0000gn/T/ipykernel_20046/310774108.py:18: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   daily_returns = prices.pct_change()
# {'name': 'ABBV', 'beta': 0.7292588694933713}
# {'name': 'ABT', 'beta': 0.8699321862443329}
# {'name': 'ACN', 'beta': 1.0728717915532737}
# {'name': 'AGN', 'beta': nan}
# {'name': 'AIG', 'beta': 1.2755818282195206}
# {'name': 'AMZN', 'beta': 1.0149209979342053}
# {'name': 'AXP', 'beta': 1.3126669522343002}
# {'name': 'BA', 'beta': 1.5319710856796984}
# {'name': 'BAC', 'beta': 1.2541657311093335}
# {'name': 'BB.TO', 'beta': 1.0730600646175206}
# {'name': 'BIIB', 'beta': 0.8288621265730518}
# {'name': 'BK', 'beta': 1.0154029222927985}
# {'name': 'BLK', 'beta': 1.201623146486655}
# {'name': 'BMY', 'beta': 0.598509147496107}
# {'name': 'C', 'beta': 1.3435023965730708}
# {'name': 'CAT', 'beta': 1.0299975521290983}
# {'name': 'CELG', 'beta': nan}
# {'name': 'CL', 'beta': 0.5633315513645609}
# {'name': 'KO', 'beta': 0.6648234202378782}
# {'name': 'LLY', 'beta': 0.6973976247800517}
# {'name': 'LMT', 'beta': 0.7122586224221193}
# {'name': 'MO', 'beta': 0.6169285988705}
# {'name': 'MON', 'beta': nan}
# {'name': 'MRK', 'beta': 0.6003562105203534}
# {'name': 'PEP', 'beta': 0.7197916407243665}
# {'name': 'PFE', 'beta': 0.6130863717728923}
# {'name': 'PG', 'beta': 0.6016333252193812}
# {'name': 'PM', 'beta': 0.7021911155879417}
# {'name': 'PYPL', 'beta': 1.3016870071113382}
# {'name': 'QCOM', 'beta': 1.2611215521835433}
# {'name': 'RTN', 'beta': nan}
# {'name': 'RY.TO', 'beta': 0.6940821066958558}
# {'name': 'SHOP.TO', 'beta': 1.314274636832347}
# {'name': 'T.TO', 'beta': 0.5217977422333376}
# {'name': 'TD.TO', 'beta': 0.7487986177118078}
# {'name': 'TXN', 'beta': 1.1716141923961072}
# {'name': 'UNH', 'beta': 0.9852546289473754}
# {'name': 'UNP', 'beta': 0.9743669242478696}
# {'name': 'UPS', 'beta': 0.8507939169129495}
# {'name': 'USB', 'beta': 1.0923762889037842}
